# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.4.1

# %%
# Data
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
# Preprocessing
train_images = train_images.astype(np.float32) / 255.
test_images = test_images.astype(np.float32) / 255.
train_images = np.expand_dims(train_images, -1)
test_images = np.expand_dims(test_images, -1)

train_labels = keras.utils.to_categorical(train_labels, 10)
test_labels = keras.utils.to_categorical(test_labels, 10)

# %%
train_images.shape
# Out:
# (60000, 28, 28, 1)

# %%
# Create Model
model = keras.Sequential();
model.add(layers.Input(shape=(28, 28, 1)))
model.add(layers.Conv2D(filters=32, kernel_size=3, padding='SAME', activation='relu', kernel_initializer='he_uniform'))
model.add(layers.MaxPool2D(padding='SAME'))
model.add(layers.Conv2D(filters=64, kernel_size=3, padding='SAME', activation='relu', kernel_initializer='he_uniform'))
model.add(layers.MaxPool2D(padding='SAME'))
model.add(layers.Conv2D(filters=128, kernel_size=3, padding='SAME', activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(units=256, activation='relu', use_bias=True, kernel_initializer='he_uniform'))
model.add(layers.Dropout(rate=0.4))
model.add(layers.Dense(units=10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 128)         73856
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               1605888
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 1,701,130
# Trainable params: 1,701,130
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train model
model.fit(train_images, train_labels, batch_size=100, epochs=15, validation_data=(test_images, test_labels))
# Out:
# Epoch 1/15
# 600/600 [==============================] - 11s 6ms/step - loss: 0.6110 - accuracy: 0.7809 - val_loss: 0.3120 - val_accuracy: 0.8834
# Epoch 2/15
# 600/600 [==============================] - 3s 5ms/step - loss: 0.2796 - accuracy: 0.8980 - val_loss: 0.2730 - val_accuracy: 0.8990
# Epoch 3/15
# 600/600 [==============================] - 3s 5ms/step - loss: 0.2331 - accuracy: 0.9131 - val_loss: 0.2425 - val_accuracy: 0.9115
# Epoch 4/15
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1946 - accuracy: 0.9281 - val_loss: 0.2258 - val_accuracy: 0.9191
# Epoch 5/15
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1680 - accuracy: 0.9376 - val_loss: 0.2150 - val_accuracy: 0.9220
# Epoch 6/15
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1472 - accuracy: 0.9461 - val_loss: 0.2242 - val_accuracy: 0.9208
# Epoch 7/15
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1288 - accuracy: 0.9516 - val_loss: 0.2360 - val_accuracy: 0.9237
# Epoch 8/15
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1146 - accuracy: 0.9577 - val_loss: 0.2248 - val_accuracy: 0.9236
# Epoch 9/15
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0987 - accuracy: 0.9626 - val_loss: 0.2481 - val_accuracy: 0.9255
# Epoch 10/15
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0831 - accuracy: 0.9693 - val_loss: 0.2508 - val_accuracy: 0.9260
# Epoch 11/15
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0713 - accuracy: 0.9722 - val_loss: 0.2804 - val_accuracy: 0.9248
# Epoch 12/15
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0632 - accuracy: 0.9769 - val_loss: 0.2898 - val_accuracy: 0.9271
# Epoch 13/15
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0562 - accuracy: 0.9783 - val_loss: 0.3087 - val_accuracy: 0.9254
# Epoch 14/15
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0502 - accuracy: 0.9816 - val_loss: 0.2967 - val_accuracy: 0.9275
# Epoch 15/15
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0444 - accuracy: 0.9837 - val_loss: 0.3633 - val_accuracy: 0.9254

# %%
# Evaluate Model
model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3633 - accuracy: 0.9254
# [0.363288938999176, 0.9254000186920166]

# %%
# Save Model
model.save('drive/MyDrive/tensorflow/practice2/fashionModel')
# Out:
# INFO:tensorflow:Assets written to: drive/MyDrive/tensorflow/practice2/fashionModel/assets
